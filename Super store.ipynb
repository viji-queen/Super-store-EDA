# %% [markdown]
# # THE SPARK FOUNDATION
# # Data science & Business Analytical Internship (march2021)

# %% [markdown]
# # NAME: Vijayalakshmi S
# # Task3:Exploratory Data Analysis - Retail

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\ELCOT\Downloads\SampleSuperstore.csv')
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data['State'].value_counts().count()
# Out:
# 49

# %%
plt.scatter(data['Category'],data['Sub-Category'])
plt.show()

# %%
sns.set_style('whitegrid')
sns.countplot(x='Region',data=data)

# %%
sns.set_style('whitegrid')
sns.countplot(x='Ship Mode',data=data)

# %%
non_profit=(data['Profit']<0).sum()
non_profit
# Out:
# 1871

# %%
loss=data.loc[data['Profit']<0]
loss
# Out:
#            Ship Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9920  Standard Class    Corporate  United States            Bryan
# 9921  Standard Class  Home Office  United States            Akron
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9962     First Class  Home Office  United States          Houston
#
#              State  Postal Code   Region         Category Sub-Category  \
# 3          Florida        33311    South        Furniture       Tables
# ...

# %% [markdown]
# # Most used Ship Mode is Standard class but at the same time loss is occured standard class only. So we have to maintain a Quality Ship Mode in Standard class.

# %%
sns.set_style('whitegrid')
sns.countplot(x='Ship Mode',data=loss)

# %%
sns.set_style('whitegrid')
sns.countplot(x='Region',data=loss)

# %%
most_loss=loss['State'].value_counts()
most_loss
# Out:
# Texas             486
# Pennsylvania      278
# Illinois          255
# Ohio              209
# Florida           126
# California        105
# Arizona            85
# North Carolina     68
# Colorado           66
# Tennessee          65
# New York           47
# Oregon             43
# Washington         17
# Massachusetts       5
# Rhode Island        4
# Delaware            2
# New Jersey          2
# Maryland            2
# Connecticut         2
# Nevada              1
# West Virginia       1
# New Hampshire       1
# New Mexico          1
# Name: State, dtype: int64

# %% [markdown]
# # To find the non-profit states

# %%
plt.figure(figsize=(5,5))
plt.hist(loss['State'],bins=10)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(5,7))
plt.pie(data['Region'].value_counts(),labels=data['Region'].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e470307550>,
# ...
#  [Text(0.587972350722521, 0.9296711863803422, 'West'),
#   Text(-1.0703729729254798, 0.2535777964070795, 'East'),
#   Text(-0.1946821397722153, -1.0826351483550272, 'Central'),
#   Text(0.960424836742563, -0.5362687133965782, 'South')])

# %%
plt.figure(figsize=(5,7))
plt.pie(data['Ship Mode'].value_counts(),labels=data['Ship Mode'].value_counts().index)
plt.legend()

# %%
plt.figure(figsize=(5,7))
plt.pie(data['State'].value_counts(),labels=data['State'].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e4703a6b20>,
# ...
#  [Text(0.8894713282515254, 0.6471790758503145, 'California'),
#   Text(-0.04597573654792534, 1.0990387762262421, 'New York'),
#   Text(-0.7136958516167541, 0.8370413558391463, 'Texas'),
#   Text(-1.0253148061303283, 0.3984087703978509, 'Pennsylvania'),
#   Text(-1.0995980671613024, 0.029733662659148643, 'Washington'),
#   Text(-1.055105106441389, -0.31105178726589144, 'Illinois'),
#   Text(-0.9147846235618942, -0.6108756767908865, 'Ohio'),
#   Text(-0.7205130839692813, -0.8311804231507595, 'Florida'),
#   Text(-0.5404901134896063, -0.9580555501744107, 'Michigan'),
#   Text(-0.38256918589964306, -1.0313296359554904, 'North Carolina'),
#   Text(-0.22556766779456197, -1.0766239952953502, 'Arizona'),
#   Text(-0.07221660828781976, -1.0976268771706548, 'Virginia'),
#   Text(0.06876586618141159, -1.097848466614733, 'Georgia'),
#   Text(0.19468202573814322, -1.082635168860911, 'Tennessee'),
# ...

# %%
plt.figure(figsize=(5,7))
plt.pie(data['City'].value_counts(),labels=data['City'].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e47049bcd0>,
# ...
#  [Text(1.0548113091579907, 0.3120466344513365, 'New York City'),
#   Text(0.7583889360942152, 0.7967723775394605, 'Los Angeles'),
#   Text(0.3845136642454052, 1.0306062497426318, 'Philadelphia'),
#   Text(0.030770631300272994, 1.0995695377052708, 'San Francisco'),
#   Text(-0.29009692906308815, 1.061057855042865, 'Seattle'),
#   Text(-0.5465026497331276, 0.9546385985464189, 'Houston'),
#   Text(-0.7393951456069869, 0.81442913666741, 'Chicago'),
#   Text(-0.8654997853023148, 0.6789036173431744, 'Columbus'),
#   Text(-0.9423830334186399, 0.5673748481600878, 'San Diego'),
#   Text(-0.9965078605892047, 0.4658026232042135, 'Springfield'),
#   Text(-1.0382471942990728, 0.36337688909739896, 'Dallas'),
#   Text(-1.0663402975647958, 0.2700340159858067, 'Jacksonville'),
#   Text(-1.083660069856953, 0.18889376114002315, 'Detroit'),
#   Text(-1.0937601811746265, 0.11699857296928265, 'Newark'),
# ...

# %%
numeric_data=data.select_dtypes(exclude='object')
numeric_data
# Out:
#       Postal Code     Sales  Quantity  Discount    Profit
# 0           42420  261.9600         2      0.00   41.9136
# 1           42420  731.9400         3      0.00  219.5820
# 2           90036   14.6200         2      0.00    6.8714
# 3           33311  957.5775         5      0.45 -383.0310
# 4           33311   22.3680         2      0.20    2.5164
# ...           ...       ...       ...       ...       ...
# 9989        33180   25.2480         3      0.20    4.1028
# 9990        92627   91.9600         2      0.00   15.6332
# 9991        92627  258.5760         2      0.20   19.3932
# 9992        92627   29.6000         4      0.00   13.3200
# 9993        92683  243.1600         2      0.00   72.9480
#
# [9994 rows x 5 columns]

# %%
figsize=(13,10)
sns.pairplot(numeric_data)

# %% [markdown]
# # Thank You
